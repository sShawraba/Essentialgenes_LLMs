# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("sms112/bact_roberta_large_essentiality")
model = AutoModelForSequenceClassification.from_pretrained("sms112/bact_roberta_large_essentiality")

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("sms112/bact_roberta_base_essentiality_Network")
model = AutoModelForSequenceClassification.from_pretrained("sms112/bact_roberta_base_essentiality_Network")
